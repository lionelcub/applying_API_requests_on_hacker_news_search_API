# %% [markdown]
# # Applying API Requests On Hacker News Search API. #
#
# ---
#
# ## Purpose of this project: ##
#
# The objective is to showcase my familiarity using API requests technique to collect data from [Hacker News Search][1]. [Here's][2] the link to the API documentation. After collecting the data, I will build a simple [data pipeline][3] to perform data cleaning.
#
# __Background info:__
#
# Hacker News is a sites where people can share stories, sites, and articles or ask questions or post hiring notices.
#
#
# ## Table of content: ##
#
# * Find an efficient API requests framework and do a test run.
#     * [Strategising the API request procedure.](#Strategising-the-API-request-procedure.)
#     * [Creating an API requests framework and do a test run.](#Creating-an-API-requests-framework-and-do-a-test-run.)
# * Implement an actual run with the API requests framework and save it into CSV file.
#     * [Implementing an actual run with created API requests framework.](#Implementing-an-actual-run-with-created-API-requests-framework.)
#     * [Save the dataset into CSV file.](#Save-the-dataset-into-CSV-file.)
# * [Notes for future reference.](#Notes-for-future-reference.)
#
# [1]:https://hn.algolia.com/
# [2]:https://hn.algolia.com/api
# [3]:https://hn.algolia.com/api
# [4]:https://hn.algolia.com/api

# %%
import requests
import pandas as pd
from pprint import pprint

# %% [markdown]
# ## Strategising the API request procedure. ##
#
# Return to [Table of content:](#Table-of-content:)
#
# ---
#
# Hacker News API limits the number of API requests from a single IP to 10,000 per hour according to the API documentation. I will have to ensure the requests runs within the rate limit at a constant interval and monitor the requests frequency to avoid breaching the rate limit rule and overloading the server. Each request page will contain 500 stories.
#
# __Here's the endpoint that I will make a `get` request to:__
#
# - __hn.algolia.com/api/v1/search_by_date?__: This endpoint will collect stories starting from the lastest date.
#
# __Here're the `get` requests parameters:__
#
# - __page:__ From page 0 to 4,999.
# - __hitsPerPage:__ 300 stories per request page.
# - __tags:__ Data must be "story" type, not "ask".
# - __numericFilters:__ Story must have more than 100 points.

# %% [markdown]
# ## Creating an API requests framework and do a test run. ##
#
# Return to [Table of content:](#Table-of-content:)
#
# ---
#
# Before doing an actual run, I will first __observe the result of the API endpoint, create an API requests framework, and do a test run.__

# %%
params = {
    "page": 0,
    "hitsPerPage": 10,
    "tags": "story",
    "numericFilters": "points > 100",
    "numericFilters": "created_at_i < 1573344000",
}

response = requests.get("https://hn.algolia.com/api/v1/search_by_date?", params=params)
print("Request status: {}".format(response.status_code))
print("Type: {}; Result: {}".format(type(response.json()), pprint(response.json())))
# Out:
# Request status: 200
# {'exhaustiveNbHits': False,
#  'hits': [{'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'doener'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'Fritz AI is the machine '
#                                                    'learning platform for iOS '
#                                                    'and Android'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'https://www.fritz.ai/'}},
#            '_tags': ['story', 'author_doener', 'story_21495397'],
#            'author': 'doener',
#            'comment_text': None,
#            'created_at': '2019-11-09T23:58:56.000Z',
#            'created_at_i': 1573343936,
#            'num_comments': 0,
#            'objectID': '21495397',
#            'parent_id': None,
#            'points': 3,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'Fritz AI is the machine learning platform for iOS and '
#                     'Android',
#            'url': 'https://www.fritz.ai/'},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'throwaway_shame'},
#                                 'story_text': {'matchLevel': 'none',
#                                                'matchedWords': [],
#                                                'value': 'I am wondering if '
#                                                         'there is a good '
#                                                         'resource(preferably a '
#                                                         'book) that details '
#                                                         'the components for '
#                                                         'building scalable '
#                                                         'APIs. I wish to learn '
#                                                         'to how to properly '
#                                                         'secure the endpoints, '
#                                                         'rate limiting, '
#                                                         'etc.<p>My background '
#                                                         'in CS is not formal '
#                                                         'but I have built a '
#                                                         'few webapps and '
#                                                         'hosted on AWS but I '
#                                                         'was never sure if I '
#                                                         'was doing it the '
#                                                         'right way. For '
#                                                         'example, I know to '
#                                                         'access DB it is '
#                                                         'better to use '
#                                                         'connection pools than '
#                                                         'not but I do not know '
#                                                         'how much of '
#                                                         'scalability this '
#                                                         'gives.<p>Secondly, I '
#                                                         'want to learn about '
#                                                         'things like how/when '
#                                                         'messaging queues are '
#                                                         'used and several '
#                                                         'other similar '
#                                                         'solutions and the '
#                                                         'drawbacks of just '
#                                                         'using a DB to achieve '
#                                                         'these '
#                                                         'functionalities.<p>Thirdly, '
#                                                         'thirdly things like '
#                                                         'how to secure the '
#                                                         'app, caching, CDNs, '
#                                                         'Load balancing '
#                                                         'etc.<p>To frame my '
#                                                         'question differently, '
#                                                         'I wish to learn about '
#                                                         'various services a '
#                                                         'Cloud vendor like AWS '
#                                                         'offers, why such a '
#                                                         'solution is '
#                                                         'necessary, what are '
#                                                         'the alternative ways '
#                                                         'of achieving '
#                                                         'something that a '
#                                                         'particular service '
#                                                         'offers and trade-offs '
#                                                         'among the '
#                                                         'alternatives and '
#                                                         'finally how to put it '
#                                                         'all together.<p>Any '
#                                                         'reference will be '
#                                                         'greatly '
#                                                         'helpful.<p>EDIT: I '
#                                                         'have specifically '
#                                                         'mentioned about APIs '
#                                                         'and not web apps to '
#                                                         'leave out the '
#                                                         'front-end aspects.'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'Ask HN: What is a good '
#                                                    'book to learn about the '
#                                                    'components of modern '
#                                                    'APIs?'}},
#            '_tags': ['story',
#                      'author_throwaway_shame',
#                      'story_21495395',
#                      'ask_hn'],
#            'author': 'throwaway_shame',
#            'comment_text': None,
#            'created_at': '2019-11-09T23:58:26.000Z',
#            'created_at_i': 1573343906,
#            'num_comments': 1,
#            'objectID': '21495395',
#            'parent_id': None,
#            'points': 4,
#            'story_id': None,
#            'story_text': 'I am wondering if there is a good '
#                          'resource(preferably a book) that details the '
#                          'components for building scalable APIs. I wish to '
#                          'learn to how to properly secure the endpoints, rate '
#                          'limiting, etc.<p>My background in CS is not formal '
#                          'but I have built a few webapps and hosted on AWS but '
#                          'I was never sure if I was doing it the right way. '
#                          'For example, I know to access DB it is better to use '
#                          'connection pools than not but I do not know how much '
#                          'of scalability this gives.<p>Secondly, I want to '
#                          'learn about things like how&#x2F;when messaging '
#                          'queues are used and several other similar solutions '
#                          'and the drawbacks of just using a DB to achieve '
#                          'these functionalities.<p>Thirdly, thirdly things '
#                          'like how to secure the app, caching, CDNs, Load '
#                          'balancing etc.<p>To frame my question differently, I '
#                          'wish to learn about various services a Cloud vendor '
#                          'like AWS offers, why such a solution is necessary, '
#                          'what are the alternative ways of achieving something '
#                          'that a particular service offers and trade-offs '
#                          'among the alternatives and finally how to put it all '
#                          'together.<p>Any reference will be greatly '
#                          'helpful.<p>EDIT: I have specifically mentioned about '
#                          'APIs and not web apps to leave out the front-end '
#                          'aspects.',
#            'story_title': None,
#            'story_url': None,
#            'title': 'Ask HN: What is a good book to learn about the components '
#                     'of modern APIs?',
#            'url': None},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'miohtama'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'Python Overtakes Java on '
#                                                    'GitHub'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'https://www.zdnet.com/article/programming-languages-python-overtakes-java-on-github-as-google-dart-use-soars/'}},
#            '_tags': ['story', 'author_miohtama', 'story_21495392'],
#            'author': 'miohtama',
#            'comment_text': None,
#            'created_at': '2019-11-09T23:58:09.000Z',
#            'created_at_i': 1573343889,
#            'num_comments': 0,
#            'objectID': '21495392',
#            'parent_id': None,
#            'points': 3,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'Python Overtakes Java on GitHub',
#            'url': 'https://www.zdnet.com/article/programming-languages-python-overtakes-java-on-github-as-google-dart-use-soars/'},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'jaboutboul'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'Phase 1 Trial of '
#                                                    'Genetically Modified '
#                                                    'Autologous Cell Therapy '
#                                                    'for HIV'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'https://www.americangene.com/press-releases/ind-application-submission-to-fda-for-phase-1-trial-of-genetically-modified-autologous-cell-therapy-for-hiv-announced-by-american-gene-technologies/'}},
#            '_tags': ['story', 'author_jaboutboul', 'story_21495386'],
#            'author': 'jaboutboul',
#            'comment_text': None,
#            'created_at': '2019-11-09T23:56:39.000Z',
#            'created_at_i': 1573343799,
#            'num_comments': 0,
#            'objectID': '21495386',
#            'parent_id': None,
#            'points': 2,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'Phase 1 Trial of Genetically Modified Autologous Cell '
#                     'Therapy for HIV',
#            'url': 'https://www.americangene.com/press-releases/ind-application-submission-to-fda-for-phase-1-trial-of-genetically-modified-autologous-cell-therapy-for-hiv-announced-by-american-gene-technologies/'},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'slackjeff'},
#                                 'story_text': {'matchLevel': 'none',
#                                                'matchedWords': [],
#                                                'value': 'WHAT?\n'
#                                                         'Are you tired of the '
#                                                         'great microblogging '
#                                                         'social media that is '
#                                                         'exploiting you? Do '
#                                                         'you just want to '
#                                                         'share some thought, '
#                                                         'somewhere simple, '
#                                                         'without these big '
#                                                         'companies getting '
#                                                         'your data? Or do you '
#                                                         'want to go back to '
#                                                         'the past, where you '
#                                                         'were looking for what '
#                                                         'you would like to '
#                                                         'read without throwing '
#                                                         'anything in your '
#                                                         'face? HackTUITE was '
#                                                         'written for this '
#                                                         'purpose, fully '
#                                                         'decentralized and '
#                                                         'minimalist. You host '
#                                                         'your own html page on '
#                                                         'your own server.\n'
#                                                         'Written in Shell '
#                                                         'Bash, for *NIX<p>FOR '
#                                                         'EXAMPLE:\n'
#                                                         'http://slackjeff.com.br/hacktuite/<p>GITHUB:\n'
#                                                         'https://github.com/slackjeff/hacktuite'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'Hacktuite (The True '
#                                                    'Decentralized Static '
#                                                    'Microblog)'}},
#            '_tags': ['story', 'author_slackjeff', 'story_21495377'],
#            'author': 'slackjeff',
#            'comment_text': None,
#            'created_at': '2019-11-09T23:54:45.000Z',
#            'created_at_i': 1573343685,
#            'num_comments': 0,
#            'objectID': '21495377',
#            'parent_id': None,
#            'points': 1,
#            'story_id': None,
#            'story_text': 'WHAT?\n'
#                          'Are you tired of the great microblogging social '
#                          'media that is exploiting you? Do you just want to '
#                          'share some thought, somewhere simple, without these '
#                          'big companies getting your data? Or do you want to '
#                          'go back to the past, where you were looking for what '
#                          'you would like to read without throwing anything in '
#                          'your face? HackTUITE was written for this purpose, '
#                          'fully decentralized and minimalist. You host your '
#                          'own html page on your own server.\n'
#                          'Written in Shell Bash, for *NIX<p>FOR EXAMPLE:\n'
#                          'http:&#x2F;&#x2F;slackjeff.com.br&#x2F;hacktuite&#x2F;<p>GITHUB:\n'
#                          'https:&#x2F;&#x2F;github.com&#x2F;slackjeff&#x2F;hacktuite',
#            'story_title': None,
#            'story_url': None,
#            'title': 'Hacktuite (The True Decentralized Static Microblog)',
#            'url': None},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'jseliger'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'Subjectivity in writing '
#                                                    'and evaluating writing '
#                                                    '(2012)'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'https://jakeseliger.com/2012/12/20/subjectivity-in-writing-and-evaluating-writing'}},
#            '_tags': ['story', 'author_jseliger', 'story_21495369'],
#            'author': 'jseliger',
#            'comment_text': None,
#            'created_at': '2019-11-09T23:52:49.000Z',
#            'created_at_i': 1573343569,
#            'num_comments': 0,
#            'objectID': '21495369',
#            'parent_id': None,
#            'points': 2,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'Subjectivity in writing and evaluating writing (2012)',
#            'url': 'https://jakeseliger.com/2012/12/20/subjectivity-in-writing-and-evaluating-writing'},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'philk10'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'How Toilet Roll Art Taught '
#                                                    'Me About Levity as a '
#                                                    'Workplace Superpower'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'https://spin.atomicobject.com/2019/11/09/toilet-paper-roll-art/#.XcdREWtEEQM.hackernews'}},
#            '_tags': ['story', 'author_philk10', 'story_21495363'],
#            'author': 'philk10',
#            'comment_text': None,
#            'created_at': '2019-11-09T23:51:48.000Z',
#            'created_at_i': 1573343508,
#            'num_comments': 0,
#            'objectID': '21495363',
#            'parent_id': None,
#            'points': 1,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'How Toilet Roll Art Taught Me About Levity as a Workplace '
#                     'Superpower',
#            'url': 'https://spin.atomicobject.com/2019/11/09/toilet-paper-roll-art/#.XcdREWtEEQM.hackernews'},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'Chancla-io'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'Chancla.io: Hello World '
#                                                    'Tutorial (Cloud-Native '
#                                                    'IDE)'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'https://www.chancla.io/hello-world-tutorial.html'}},
#            '_tags': ['story', 'author_Chancla-io', 'story_21495356'],
#            'author': 'Chancla-io',
#            'comment_text': None,
#            'created_at': '2019-11-09T23:50:09.000Z',
#            'created_at_i': 1573343409,
#            'num_comments': 0,
#            'objectID': '21495356',
#            'parent_id': None,
#            'points': 1,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'Chancla.io: Hello World Tutorial (Cloud-Native IDE)',
#            'url': 'https://www.chancla.io/hello-world-tutorial.html'},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'tomohawk'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': '1k Feeder Ship to Test '
#                                                    'Carbon-Neutral Synthetic '
#                                                    'Natural Gas'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'https://gcaptain.com/1000-feeder-ship-to-test-carbon-neutral-synthetic-natural-gas/'}},
#            '_tags': ['story', 'author_tomohawk', 'story_21495351'],
#            'author': 'tomohawk',
#            'comment_text': None,
#            'created_at': '2019-11-09T23:48:35.000Z',
#            'created_at_i': 1573343315,
#            'num_comments': 0,
#            'objectID': '21495351',
#            'parent_id': None,
#            'points': 1,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': '1k Feeder Ship to Test Carbon-Neutral Synthetic Natural '
#                     'Gas',
#            'url': 'https://gcaptain.com/1000-feeder-ship-to-test-carbon-neutral-synthetic-natural-gas/'},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'justin66'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'Rust 2020: GUI and '
#                                                    'Community'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'https://raphlinus.github.io/rust/druid/2019/10/31/rust-2020.html'}},
#            '_tags': ['story',
#                      'author_justin66',
#                      'story_21495338',
#                      'front_page'],
#            'author': 'justin66',
#            'comment_text': None,
#            'created_at': '2019-11-09T23:46:07.000Z',
#            'created_at_i': 1573343167,
#            'num_comments': 35,
#            'objectID': '21495338',
#            'parent_id': None,
#            'points': 142,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'Rust 2020: GUI and Community',
#            'url': 'https://raphlinus.github.io/rust/druid/2019/10/31/rust-2020.html'}],
#  'hitsPerPage': 10,
#  'nbHits': 1918699,
#  'nbPages': 100,
#  'page': 0,
#  'params': 'advancedSyntax=true&analytics=true&analyticsTags=backend&hitsPerPage=10&numericFilters=created_at_i+%3C+1573344000&page=0&tags=story',
#  'processingTimeMS': 3,
#  'query': ''}
# Type: <class 'dict'>; Result: None

# %% [markdown]
# ---
#
# The requests to the API endpoint is successful. The collected data is a __"story" type__ and the stories are __ordered by date__ starting from the latest. Each story contains __more than 100 points__. Next is to ensure the `hitsPerPage` outputs __500 stories__ exactly. The `hits` key inside the dictionary contains a list of all the stories. Hence, I only have to count the length of the list in order to find out the number of results.

# %%
params = {
    "page": 0,
    "hitsPerPage": 500,
    "tags": "story",
    "numericFilters": "points > 100",
    "numericFilters": "created_at_i < 1573344000",
}

response = requests.get("https://hn.algolia.com/api/v1/search_by_date?", params=params)
print("Request status: {}".format(response.status_code))
print("Type: {}; Result: {}".format(type(response.json()), len(response.json()["hits"])))
# Out:
# Request status: 200
# Type: <class 'dict'>; Result: 500

# %% [markdown]
# ---
#
# Looking at the result above, the request outputs 500 stories exactly. The next step is __locate the target keys__ inside the dictionary in order to collect relevant data for analysis.
#
# __Here're the target keys that can be useful for analysis later:__
#
# 1. __objectID:__ It is a story ID. Might be useful if I need to make an API request to gather more information on this specific story via __hn.algolia.com/api/v1/items/:id__ endpoint.
# 1. __title:__ For finding out the topic.
# 1. __created_at:__ For determining how current the story is.
# 1. __points:__ For measuring the popularity of the story.
# 1. __num_comments:__ For measuring the readers' participation and interest on the particular story.
# 1. __url:__ For finding the most referred sites.
#
# The `hits` key inside the dictionary contains a list of all the stories. Hence, I just have to convert the list of stories into a DataFrame and filter the columns by the target keys.

# %%
ls_hits = response.json()["hits"]

columns = [
    "objectID", "title", "created_at", "points", "num_comments", "url"
]

pd.DataFrame(data=ls_hits)[columns]
# Out:
#      objectID                                              title  \
# 0    21495397  Fritz AI is the machine learning platform for ...
# 1    21495395  Ask HN: What is a good book to learn about the...
# 2    21495392                    Python Overtakes Java on GitHub
# 3    21495386  Phase 1 Trial of Genetically Modified Autologo...
# 4    21495377  Hacktuite (The True Decentralized Static Micro...
# ..        ...                                                ...
# 495  21489568  TikTok time-bomb: Silly clips raise some serio...
# 496  21489539  Ask HN: What are the best resources for learni...
# 497  21489492                    Brains Create Identical Objects
# 498  21489469  Ask HN: Why aren't more companies source code ...
# 499  21489456        One year of Sensu Go – and licensing change
#
#                    created_at  points  num_comments  \
# 0    2019-11-09T23:58:56.000Z       3             0
# 1    2019-11-09T23:58:26.000Z       4             1
# 2    2019-11-09T23:58:09.000Z       3             0
# 3    2019-11-09T23:56:39.000Z       2             0
# 4    2019-11-09T23:54:45.000Z       1             0
# ..                        ...     ...           ...
# 495  2019-11-09T04:19:40.000Z       2             0
# 496  2019-11-09T04:12:52.000Z      63            13
# 497  2019-11-09T04:00:01.000Z       3             0
# 498  2019-11-09T03:55:51.000Z       1             1
# 499  2019-11-09T03:52:13.000Z       1             0
#
#                                                    url
# 0                                https://www.fritz.ai/
# 1                                                 None
# 2    https://www.zdnet.com/article/programming-lang...
# 3    https://www.americangene.com/press-releases/in...
# 4                                                 None
# ..                                                 ...
# 495  https://www.economist.com/business/2019/11/07/...
# 496                                               None
# 497           https://www.scaruffi.com/phi/syn220.html
# 498                                               None
# 499         https://blog.sensu.io/one-year-of-sensu-go
#
# [500 rows x 6 columns]

# %% [markdown]
# ---
#
# __Find the maximum request frequency to avoid breaching the rate limit rule.__

# %%
# This is to find the maximum request frequency to avoid breaching the rate limit rule. 
def rate_limit(total_requests, seconds):
    rate_limit = total_requests / seconds
    print("Request: {}; Max frequency: {} requests/s".format(total_requests, rate_limit))
    
rate_limit(10000, 3600)
# Out:
# Request: 10000; Max frequency: 2.7777777777777777 requests/s

# %% [markdown]
# ---
#
# Looking at the result above, the request frequency should not exceed 2.7 requests per second. If I were to make 1 request per second, it will take 1,000 seconds to complete it, which is about 17 minutes.

# %% [markdown]
# __Find the optimal request rate.__

# %%
def optimal_request_rate(n_requests, sleep_time):
    from time import time, sleep
    from IPython.core.display import clear_output
    
    # Create a 'requested' variable to keep track of the current request made.
    requested = 0
    # Time the request to track the request frequency.
    start = time() 
    
    for n in range(0, n_requests):
        requested += 1
        sleep(sleep_time)

        elapsed_time = time() - start

        print("Request: {}; Frequency: {} requests/s".format(requested, requested / elapsed_time))
        clear_output(wait=True)
        
optimal_request_rate(10, 1)
# Out:
# Request: 10; Frequency: 0.9948941246319378 requests/s

# %%
params = {
    "page": 0,
    "hitsPerPage": 500,
    "tags": "story",
    "numericFilters": "points > 100",
    "numericFilters": "created_at_i < 1573344000",
}

target_keys = [
    "objectID", "title", "created_at", "points", "num_comments", "url"
]

url = "https://hn.algolia.com/api/v1/search_by_date?"

def api_requests(n_requests, url, sleep_time, target_keys=None, params={}):
    import numpy as np
    from time import time, sleep
    from IPython.core.display import clear_output
    from warnings import warn
    
    # Create a list to store unsuccessful requests for reference later.
    # Create a 'requested' variable to keep track of the current request made.
    request_failed = np.array([])
    requested = 0
    
    # Create empty DataFrame to store the data.
    df = pd.DataFrame(data=[])

    # Time the request to ensure it is staying within the rate limit.
    start = time() 
    # Set the parameters when the running the api requests.
    params_dict = params.copy()

    # Make n number of requests, which equals to n pages.
    for page in range(0, n_requests):

        # Break the loop if the total request is greater than n_requests (just in case).
        if requested > n_requests:
            warn("Request number is greater than {}}.".format(n_requests))
            break
            
        requested += 1
        response = requests.get("{}".format(url), params=params_dict)
        
        # Rewrite the page number for each request.
        params_dict["page"] += 1
        
        # Sleep for n seconds.
        sleep(sleep_time)
        elapsed_time = time() - start
        
        # Warn unsuccessful status code.
        if response.status_code != 200:
            warn('Request: {}; Status code: {}'.format(requested, response.status_code))
            request_failed = np.append(request_failed, [requested, response.status_code])
        
        # Append the items to the list if the request is successful.
        if response.status_code == 200:
            ls_data = response.json()["hits"]
        
        # Print out the number of requests and time to monitor the progress.
        print("Request: {}; Frequency: {} requests/s".format(requested, requested / elapsed_time))
        clear_output(wait=True)
        
        # If the requests outputs 0 result, stop the API requests.
        results = len(response.json()["hits"])
        if  results == 0:
            warn("Request outputs no more result.")
            return df, request_failed
        
        # Add the collected data to DataFrame. 
        if target_keys: 
            df_collected_data = pd.DataFrame(data=ls_data)[target_keys]
        else:
            df_collected_data = pd.DataFrame(data=ls_data)
        df = pd.concat(objs=[df, df_collected_data], axis=0, join='outer')

    return df, request_failed

# %% [markdown]
# __Do a test run with only 5 API requests.__

# %%
hn_stories, request_failed = api_requests(n_requests=5, url=url, sleep_time=1, 
                                          target_keys=target_keys, params=params)
# Out:
# /Users/lioneltay/Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:68: UserWarning: Request outputs no more result.

# %%
hn_stories
# Out:
#      objectID                                              title  \
# 0    21495397  Fritz AI is the machine learning platform for ...
# 1    21495395  Ask HN: What is a good book to learn about the...
# 2    21495392                    Python Overtakes Java on GitHub
# 3    21495386  Phase 1 Trial of Genetically Modified Autologo...
# 4    21495377  Hacktuite (The True Decentralized Static Micro...
# ..        ...                                                ...
# 495  21482808  Edge on Chromium: Stable Release Comes at the ...
# 496  21482806  Sir Martin Sorrell’s Silicon Valley Charm Offe...
# 497  21482795  Kubernetes development, simplified–Skaffold is...
# 498  21482781                        How to Land a Journal Cover
# 499  21482733  Build Data-Driven GitHub Badges with Node.js a...
#
#                    created_at  points  num_comments  \
# 0    2019-11-09T23:58:56.000Z       3             0
# 1    2019-11-09T23:58:26.000Z       4             1
# 2    2019-11-09T23:58:09.000Z       3             0
# 3    2019-11-09T23:56:39.000Z       2             0
# 4    2019-11-09T23:54:45.000Z       1             0
# ..                        ...     ...           ...
# 495  2019-11-08T15:05:20.000Z       4             0
# 496  2019-11-08T15:05:10.000Z       1             0
# 497  2019-11-08T15:03:21.000Z       3             0
# 498  2019-11-08T15:01:40.000Z       3             0
# 499  2019-11-08T14:57:03.000Z       1             0
#
#                                                    url
# 0                                https://www.fritz.ai/
# 1                                                 None
# 2    https://www.zdnet.com/article/programming-lang...
# 3    https://www.americangene.com/press-releases/in...
# 4                                                 None
# ..                                                 ...
# 495  https://techplanet.today/post/edge-on-chromium...
# 496  https://techcrunch.com/2019/11/07/sir-martin-s...
# 497  https://cloud.google.com/blog/products/applica...
# 498  https://www.nature.com/articles/d41586-019-003...
# 499       https://www.openfaas.com/blog/github-badges/
#
# [1000 rows x 6 columns]

# %%
request_failed
# Out:
# array([], dtype=float64)

# %%
hn_stories.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ---
#
# The API requests framework is successful and there is no failed request. The only the exception is that the time interval between each request was halfed, so there might be room to lower the `sleep_time` slightly.

# %% [markdown]
# ## Implementing an actual run with created API requests framework. ##
#
# Return to [Table of content:](#Table-of-content:)

# %%
hn_stories, request_failed = api_requests(n_requests=1000, url=url, sleep_time=.75, 
                                          target_keys=target_keys, params=params)
# Out:
# /Users/lioneltay/Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:68: UserWarning: Request outputs no more result.

# %%
hn_stories
# Out:
#      objectID                                              title  \
# 0    21495397  Fritz AI is the machine learning platform for ...
# 1    21495395  Ask HN: What is a good book to learn about the...
# 2    21495392                    Python Overtakes Java on GitHub
# 3    21495386  Phase 1 Trial of Genetically Modified Autologo...
# 4    21495377  Hacktuite (The True Decentralized Static Micro...
# ..        ...                                                ...
# 495  21482808  Edge on Chromium: Stable Release Comes at the ...
# 496  21482806  Sir Martin Sorrell’s Silicon Valley Charm Offe...
# 497  21482795  Kubernetes development, simplified–Skaffold is...
# 498  21482781                        How to Land a Journal Cover
# 499  21482733  Build Data-Driven GitHub Badges with Node.js a...
#
#                    created_at  points  num_comments  \
# 0    2019-11-09T23:58:56.000Z       3             0
# 1    2019-11-09T23:58:26.000Z       4             1
# 2    2019-11-09T23:58:09.000Z       3             0
# 3    2019-11-09T23:56:39.000Z       2             0
# 4    2019-11-09T23:54:45.000Z       1             0
# ..                        ...     ...           ...
# 495  2019-11-08T15:05:20.000Z       4             0
# 496  2019-11-08T15:05:10.000Z       1             0
# 497  2019-11-08T15:03:21.000Z       3             0
# 498  2019-11-08T15:01:40.000Z       3             0
# 499  2019-11-08T14:57:03.000Z       1             0
#
#                                                    url
# 0                                https://www.fritz.ai/
# 1                                                 None
# 2    https://www.zdnet.com/article/programming-lang...
# 3    https://www.americangene.com/press-releases/in...
# 4                                                 None
# ..                                                 ...
# 495  https://techplanet.today/post/edge-on-chromium...
# 496  https://techcrunch.com/2019/11/07/sir-martin-s...
# 497  https://cloud.google.com/blog/products/applica...
# 498  https://www.nature.com/articles/d41586-019-003...
# 499       https://www.openfaas.com/blog/github-badges/
#
# [1000 rows x 6 columns]

# %%
request_failed
# Out:
# array([], dtype=float64)

# %% [markdown]
# ## Save the dataset into CSV file. ##
#
# Return to [Table of content:](#Table-of-content:)
#
# ---
# __Save the dataset as .csv format.__

# %%
hn_stories.to_csv("hn_stories.csv", index=False, header=True, sep=",")

# %% [markdown]
# ## Notes for future reference. ##
#
# __List of things to take note in the future:__
#
# * The API endpoints may have changed.
# * Useful data such as `points` and `num_comments` may be outdated.
# * Hacker News might impose a requirement for API authentication.
# * Terms & condition, and license may be updated. It might introduce some limitations to data usage.
#
# Return to [Table of content:](#Table-of-content:)
