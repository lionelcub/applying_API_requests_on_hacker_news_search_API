# %% [markdown]
# # Applying API Requests On Hacker News Search API. #
#
# ---
#
# ## Purpose of this project: ##
#
# The objective is to showcase my familiarity using API requests technique to collect data from [Hacker News Search][1]. [Here's][2] the link to the API documentation. I will be collecting about 500,000 stories data from Hacker News. After collecting the data, I will build a simple [data pipeline][3] to perform data cleaning.
#
# __Background info:__
#
# Hacker News is a sites where people can share stories, sites, and articles or ask questions or post hiring notices.
#
#
# ## Table of content: ##
#
# * Find an efficient API requests framework and do a test run.
#     * [Strategising the API request procedure.](#Strategising-the-API-request-procedure.)
#     * [Creating an API requests framework and do a test run.](#Creating-an-API-requests-framework-and-do-a-test-run.)
# * Implement an actual run with the API requests framework and save it into CSV file.
#     * [Implementing an actual run with created API requests framework.](#Implementing-an-actual-run-with-created-API-requests-framework.)
#     * [Save the dataset into CSV file.](#Save-the-dataset-into-CSV-file.)
# * [Notes for future reference.](#Notes-for-future-reference.)
#
# [1]:https://hn.algolia.com/
# [2]:https://hn.algolia.com/api
# [3]:https://hn.algolia.com/api
# [4]:https://hn.algolia.com/api

# %%
import requests
import pandas as pd
from pprint import pprint

# %% [markdown]
# ## Strategising the API request procedure. ##
#
# Return to [Table of content:](#Table-of-content:)
#
# ---
#
# Hacker News API limits the number of API requests from a single IP to 10,000 per hour according to the API documentation. I will have to ensure the requests runs within the rate limit at a constant interval and monitor the requests frequency to avoid breaching the rate limit rule and overloading the server. It will take 1,000 requests to collect about 500,000 stories data if each request page is able to contain 500 stories.
#
# __Here's the endpoint that I will make a `get` request to:__
#
# - __hn.algolia.com/api/v1/search_by_date?__: This endpoint will collect stories starting from the lastest date.
#
# __Here're the `get` requests parameters:__
#
# - __page:__ From page 0 to 4,999.
# - __hitsPerPage:__ 300 stories per request page.
# - __tags:__ Data must be "story" type, not "ask".
# - __numericFilters:__ Story must have more than 100 points.

# %% [markdown]
# ## Creating an API requests framework and do a test run. ##
#
# Return to [Table of content:](#Table-of-content:)
#
# ---
#
# Before doing an actual run, I will first __observe the result of the API endpoint, create an API requests framework, and do a test run.__

# %%
params = {
    "page": 0,
    "hitsPerPage": 10,
    "tags": "story",
    "numericFilters": "points > 100"
}

response = requests.get("https://hn.algolia.com/api/v1/search_by_date?", params=params)
print("Request status: {}".format(response.status_code))
print("Type: {}; Result: {}".format(type(response.json()), pprint(response.json())))
# Out:
# Request status: 200
# {'exhaustiveNbHits': False,
#  'hits': [{'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'yskchu'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'Now Googlers Are '
#                                                    'Protesting Company’s Deals '
#                                                    'with Big Oil'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'https://www.bloomberg.com/news/articles/2019-11-04/now-googlers-are-protesting-company-s-cloud-deals-with-big-oil'}},
#            '_tags': ['story', 'author_yskchu', 'story_21451917', 'front_page'],
#            'author': 'yskchu',
#            'comment_text': None,
#            'created_at': '2019-11-05T12:55:24.000Z',
#            'created_at_i': 1572958524,
#            'num_comments': 142,
#            'objectID': '21451917',
#            'parent_id': None,
#            'points': 124,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'Now Googlers Are Protesting Company’s Deals with Big Oil',
#            'url': 'https://www.bloomberg.com/news/articles/2019-11-04/now-googlers-are-protesting-company-s-cloud-deals-with-big-oil'},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'nuriaion'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'Facebook Libra Is '
#                                                    'Architecturally Unsound'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'http://www.stephendiehl.com/posts/libra.html'}},
#            '_tags': ['story',
#                      'author_nuriaion',
#                      'story_21451847',
#                      'front_page'],
#            'author': 'nuriaion',
#            'comment_text': None,
#            'created_at': '2019-11-05T12:44:52.000Z',
#            'created_at_i': 1572957892,
#            'num_comments': 113,
#            'objectID': '21451847',
#            'parent_id': None,
#            'points': 251,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'Facebook Libra Is Architecturally Unsound',
#            'url': 'http://www.stephendiehl.com/posts/libra.html'},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'pionerkotik'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'The Windows Update '
#                                                    'Marathon in a VM: From '
#                                                    'Windows 1.01 to XP'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'https://www.winhistory.de/more/386/updatem.htm'}},
#            '_tags': ['story',
#                      'author_pionerkotik',
#                      'story_21451434',
#                      'front_page'],
#            'author': 'pionerkotik',
#            'comment_text': None,
#            'created_at': '2019-11-05T11:36:56.000Z',
#            'created_at_i': 1572953816,
#            'num_comments': 78,
#            'objectID': '21451434',
#            'parent_id': None,
#            'points': 154,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'The Windows Update Marathon in a VM: From Windows 1.01 to '
#                     'XP',
#            'url': 'https://www.winhistory.de/more/386/updatem.htm'},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'bcaa7f3a8bbc'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'Unofficial Windows XP SP4'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'https://ryanvm.net/forum/viewtopic.php?t=10321'}},
#            '_tags': ['story',
#                      'author_bcaa7f3a8bbc',
#                      'story_21450402',
#                      'front_page'],
#            'author': 'bcaa7f3a8bbc',
#            'comment_text': None,
#            'created_at': '2019-11-05T07:29:09.000Z',
#            'created_at_i': 1572938949,
#            'num_comments': 77,
#            'objectID': '21450402',
#            'parent_id': None,
#            'points': 123,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'Unofficial Windows XP SP4',
#            'url': 'https://ryanvm.net/forum/viewtopic.php?t=10321'},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'happy-go-lucky'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'Free Online Courses from '
#                                                    'Top Universities'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'http://www.openculture.com/freeonlinecourses'}},
#            '_tags': ['story',
#                      'author_happy-go-lucky',
#                      'story_21450126',
#                      'front_page'],
#            'author': 'happy-go-lucky',
#            'comment_text': None,
#            'created_at': '2019-11-05T06:17:18.000Z',
#            'created_at_i': 1572934638,
#            'num_comments': 33,
#            'objectID': '21450126',
#            'parent_id': None,
#            'points': 237,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'Free Online Courses from Top Universities',
#            'url': 'http://www.openculture.com/freeonlinecourses'},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'bryanrasmussen'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'The Lost Key of QWERTY '
#                                                    '(2016)'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'http://widespacer.blogspot.com/2016/03/the-lost-key-of-qwerty.html'}},
#            '_tags': ['story',
#                      'author_bryanrasmussen',
#                      'story_21449919',
#                      'front_page'],
#            'author': 'bryanrasmussen',
#            'comment_text': None,
#            'created_at': '2019-11-05T05:34:31.000Z',
#            'created_at_i': 1572932071,
#            'num_comments': 63,
#            'objectID': '21449919',
#            'parent_id': None,
#            'points': 150,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'The Lost Key of QWERTY (2016)',
#            'url': 'http://widespacer.blogspot.com/2016/03/the-lost-key-of-qwerty.html'},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'feelthepress'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'How to Set Your Google '
#                                                    'Data to Self-Destruct'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'https://www.nytimes.com/2019/10/02/technology/personaltech/google-data-self-destruct-privacy.html'}},
#            '_tags': ['story',
#                      'author_feelthepress',
#                      'story_21449444',
#                      'front_page'],
#            'author': 'feelthepress',
#            'comment_text': None,
#            'created_at': '2019-11-05T03:52:08.000Z',
#            'created_at_i': 1572925928,
#            'num_comments': 49,
#            'objectID': '21449444',
#            'parent_id': None,
#            'points': 110,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'How to Set Your Google Data to Self-Destruct',
#            'url': 'https://www.nytimes.com/2019/10/02/technology/personaltech/google-data-self-destruct-privacy.html'},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'peter_d_sherman'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'What does the Laplace '
#                                                    'Transform tell us? A '
#                                                    'visual explanation '
#                                                    '[video]'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'https://www.youtube.com/watch?v=n2y7n6jw5d0'}},
#            '_tags': ['story',
#                      'author_peter_d_sherman',
#                      'story_21449203',
#                      'front_page'],
#            'author': 'peter_d_sherman',
#            'comment_text': None,
#            'created_at': '2019-11-05T03:00:58.000Z',
#            'created_at_i': 1572922858,
#            'num_comments': 25,
#            'objectID': '21449203',
#            'parent_id': None,
#            'points': 192,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'What does the Laplace Transform tell us? A visual '
#                     'explanation [video]',
#            'url': 'https://www.youtube.com/watch?v=n2y7n6jw5d0'},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'ArtWomb'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'Few-Shot Video-to-Video '
#                                                    'Synthesis'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'https://nvlabs.github.io/few-shot-vid2vid/'}},
#            '_tags': ['story', 'author_ArtWomb', 'story_21448449', 'front_page'],
#            'author': 'ArtWomb',
#            'comment_text': None,
#            'created_at': '2019-11-05T00:41:25.000Z',
#            'created_at_i': 1572914485,
#            'num_comments': 37,
#            'objectID': '21448449',
#            'parent_id': None,
#            'points': 167,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'Few-Shot Video-to-Video Synthesis',
#            'url': 'https://nvlabs.github.io/few-shot-vid2vid/'},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'dredmorbius'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'Regulating Big Tech makes '
#                                                    'them stronger, so they '
#                                                    'need competition instead'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'https://www.economist.com/open-future/2019/06/06/regulating-big-tech-makes-them-stronger-so-they-need-competition-instead'}},
#            '_tags': ['story',
#                      'author_dredmorbius',
#                      'story_21448078',
#                      'front_page'],
#            'author': 'dredmorbius',
#            'comment_text': None,
#            'created_at': '2019-11-04T23:50:22.000Z',
#            'created_at_i': 1572911422,
#            'num_comments': 98,
#            'objectID': '21448078',
#            'parent_id': None,
#            'points': 164,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'Regulating Big Tech makes them stronger, so they need '
#                     'competition instead',
#            'url': 'https://www.economist.com/open-future/2019/06/06/regulating-big-tech-makes-them-stronger-so-they-need-competition-instead'}],
#  'hitsPerPage': 10,
#  'nbHits': 103061,
#  'nbPages': 100,
#  'page': 0,
#  'params': 'advancedSyntax=true&analytics=true&analyticsTags=backend&hitsPerPage=10&numericFilters=points+%3E+100&page=0&tags=story',
#  'processingTimeMS': 5,
#  'query': ''}
# Type: <class 'dict'>; Result: None

# %% [markdown]
# ---
#
# The requests to the API endpoint is successful. The collected data is a __"story" type__ and the stories are __ordered by date__ starting from the latest. Each story contains __more than 100 points__. Next is to ensure the `hitsPerPage` outputs __500 stories__ exactly. The `hits` key inside the dictionary contains a list of all the stories. Hence, I only have to count the length of the list in order to find out the number of results.

# %%
params = {
    "page": 0,
    "hitsPerPage": 500,
    "tags": "story",
    "numericFilters": "points > 100",
}

response = requests.get("https://hn.algolia.com/api/v1/search_by_date?", params=params)
print("Request status: {}".format(response.status_code))
print("Type: {}; Result: {}".format(type(response.json()), len(response.json()["hits"])))
# Out:
# Request status: 200
# Type: <class 'dict'>; Result: 500

# %% [markdown]
# ---
#
# Looking at the result above, the request outputs 500 stories exactly. The next step is __locate the target keys__ inside the dictionary in order to collect relevant data for analysis.
#
# __Here're the target keys that can be useful for analysis later:__
#
# 1. __objectID:__ It is a story ID. Might be useful if I need to make an API request to gather more information on this specific story via __hn.algolia.com/api/v1/items/:id__ endpoint.
# 1. __title:__ For finding out the topic.
# 1. __created_at:__ For determining how current the story is.
# 1. __points:__ For measuring the popularity of the story.
# 1. __num_comments:__ For measuring the readers' participation and interest on the particular story.
# 1. __url:__ For finding the most referred sites.
#
# The `hits` key inside the dictionary contains a list of all the stories. Hence, I just have to convert the list of stories into a DataFrame and filter the columns by the target keys.

# %%
ls_hits = response.json()["hits"]

columns = [
    "objectID", "title", "created_at", "points", "num_comments", "url"
]

pd.DataFrame(data=ls_hits)[columns]
# Out:
#      objectID                                              title  \
# 0    21451917  Now Googlers Are Protesting Company’s Deals wi...
# 1    21451847          Facebook Libra Is Architecturally Unsound
# 2    21451434  The Windows Update Marathon in a VM: From Wind...
# 3    21450402                          Unofficial Windows XP SP4
# 4    21450126          Free Online Courses from Top Universities
# ..        ...                                                ...
# 495  21345142  Obscure Charges That Utility Companies Add to ...
# 496  21344522             Congressman's phone password is 111111
# 497  21343989  Show HN: Passbox – Give access to your data on...
# 498  21343860                         Web Based Qt Design Viewer
# 499  21343761          Gitlab ‘rethinking’ third-party telemetry
#
#                    created_at  points  num_comments  \
# 0    2019-11-05T12:55:24.000Z     124           142
# 1    2019-11-05T12:44:52.000Z     251           113
# 2    2019-11-05T11:36:56.000Z     154            78
# 3    2019-11-05T07:29:09.000Z     123            77
# 4    2019-11-05T06:17:18.000Z     237            33
# ..                        ...     ...           ...
# 495  2019-10-24T14:43:18.000Z     119            29
# 496  2019-10-24T13:36:35.000Z     321           194
# 497  2019-10-24T12:32:52.000Z     110           133
# 498  2019-10-24T12:19:35.000Z     132            88
# 499  2019-10-24T12:07:36.000Z     623           347
#
#                                                    url
# 0    https://www.bloomberg.com/news/articles/2019-1...
# 1         http://www.stephendiehl.com/posts/libra.html
# 2       https://www.winhistory.de/more/386/updatem.htm
# 3       https://ryanvm.net/forum/viewtopic.php?t=10321
# 4         http://www.openculture.com/freeonlinecourses
# ..                                                 ...
# 495  https://www.propublica.org/article/the-obscure...
# 496           https://gfycat.com/uncommonacclaimedboar
# 497                                 https://passbox.co
# 498  https://www.qt.io/blog/web-based-qt-design-viewer
# 499   https://gitlab.com/gitlab-org/gitaly/issues/2113
#
# [500 rows x 6 columns]

# %% [markdown]
# ---
#
# __Find the maximum request frequency to avoid breaching the rate limit rule.__

# %%
# This is to find the maximum request frequency to avoid breaching the rate limit rule. 
def rate_limit(total_requests, seconds):
    rate_limit = total_requests / seconds
    print("Request: {}; Max frequency: {} requests/s".format(total_requests, rate_limit))
    
rate_limit(10000, 3600)
# Out:
# Request: 10000; Max frequency: 2.7777777777777777 requests/s

# %% [markdown]
# ---
#
# Looking at the result above, the request frequency should not exceed 2.7 requests per second. If I were to make 1 request per second, it will take 1,000 seconds to complete it, which is about 17 minutes.

# %% [markdown]
# __Find the optimal request rate.__

# %%
def optimal_request_rate(n_requests, sleep_time):
    from time import time, sleep
    from IPython.core.display import clear_output
    
    # Create a 'requested' variable to keep track of the current request made.
    requested = 0
    # Time the request to track the request frequency.
    start = time() 
    
    for n in range(0, n_requests):
        requested += 1
        sleep(sleep_time)

        elapsed_time = time() - start

        print("Request: {}; Frequency: {} requests/s".format(requested, requested / elapsed_time))
        clear_output(wait=True)
        
optimal_request_rate(10, 1)
# Out:
# Request: 10; Frequency: 0.9953925021145811 requests/s

# %%
params = {
    "page": 0,
    "hitsPerPage": 500,
    "tags": "story",
    "numericFilters": "points > 100",
}

target_keys = [
    "objectID", "title", "created_at", "points", "num_comments", "url"
]

url = "https://hn.algolia.com/api/v1/search_by_date?"

def api_requests(n_requests, url, sleep_time, target_keys=None, params={}):
    import numpy as np
    from time import time, sleep
    from IPython.core.display import clear_output
    from warnings import warn
    
    # Create a list to store unsuccessful requests for reference later.
    # Create a 'requested' variable to keep track of the current request made.
    request_failed = np.array([])
    requested = 0
    
    # Create empty DataFrame to store the data.
    df = pd.DataFrame(data=[])

    # Time the request to ensure it is staying within the rate limit.
    start = time() 
    # Set the parameters when the running the api requests.
    params = params

    # Make n number of requests, which equals to n pages.
    for page in range(0, n_requests):

        # Break the loop if the total request is greater than n_requests (just in case).
        if requested > n_requests:
            warn("Request number is greater than {}}.".format(n_requests))
            break
            
        requested += 1
        response = requests.get("{}".format(url), params=params)
        
        # Sleep for n seconds.
        sleep(sleep_time)
        elapsed_time = time() - start
        
        # Warn unsuccessful status code.
        if response.status_code != 200:
            warn('Request: {}; Status code: {}'.format(requested, response.status_code))
            request_failed = np.append(request_failed, [requested, response.status_code])
        
        # Append the items to the list if the request is successful.
        if response.status_code == 200:
            ls_data = response.json()["hits"]
        
        # Print out the number of requests and time to monitor the progress.
        print("Request: {}; Frequency: {} requests/s".format(requested, requested / elapsed_time))
        clear_output(wait=True)
        
        # Add the collected data to DataFrame. 
        if target_keys: 
            df_collected_data = pd.DataFrame(data=ls_data)[target_keys]
        else:
            df_collected_data = pd.DataFrame(data=ls_data)
        df = pd.concat(objs=[df, df_collected_data], axis=0)

    return df, request_failed

# %% [markdown]
# __Do a test run with only 5 API requests.__

# %%
hn_stories, request_failed = api_requests(n_requests=5, url=url, sleep_time=1, 
                                       target_keys=target_keys, params=params)
# Out:
# Request: 5; Frequency: 0.4291873916544104 requests/s

# %%
hn_stories
# Out:
#      objectID                                              title  \
# 0    21451917  Now Googlers Are Protesting Company’s Deals wi...
# 1    21451847          Facebook Libra Is Architecturally Unsound
# 2    21451434  The Windows Update Marathon in a VM: From Wind...
# 3    21450402                          Unofficial Windows XP SP4
# 4    21450126          Free Online Courses from Top Universities
# ..        ...                                                ...
# 495  21345142  Obscure Charges That Utility Companies Add to ...
# 496  21344522             Congressman's phone password is 111111
# 497  21343989  Show HN: Passbox – Give access to your data on...
# 498  21343860                         Web Based Qt Design Viewer
# 499  21343761          Gitlab ‘rethinking’ third-party telemetry
#
#                    created_at  points  num_comments  \
# 0    2019-11-05T12:55:24.000Z     125           142
# 1    2019-11-05T12:44:52.000Z     251           113
# 2    2019-11-05T11:36:56.000Z     154            78
# 3    2019-11-05T07:29:09.000Z     123            77
# 4    2019-11-05T06:17:18.000Z     237            33
# ..                        ...     ...           ...
# 495  2019-10-24T14:43:18.000Z     119            29
# 496  2019-10-24T13:36:35.000Z     321           194
# 497  2019-10-24T12:32:52.000Z     110           133
# 498  2019-10-24T12:19:35.000Z     132            88
# 499  2019-10-24T12:07:36.000Z     623           347
#
#                                                    url
# 0    https://www.bloomberg.com/news/articles/2019-1...
# 1         http://www.stephendiehl.com/posts/libra.html
# 2       https://www.winhistory.de/more/386/updatem.htm
# 3       https://ryanvm.net/forum/viewtopic.php?t=10321
# 4         http://www.openculture.com/freeonlinecourses
# ..                                                 ...
# 495  https://www.propublica.org/article/the-obscure...
# 496           https://gfycat.com/uncommonacclaimedboar
# 497                                 https://passbox.co
# 498  https://www.qt.io/blog/web-based-qt-design-viewer
# 499   https://gitlab.com/gitlab-org/gitaly/issues/2113
#
# [2500 rows x 6 columns]

# %%
request_failed
# Out:
# array([], dtype=float64)

# %% [markdown]
# ---
#
# The API requests framework is successful and there is no failed request. The only the exception is that the time interval between each request was halfed, so there might be room to lower the `sleep_time` slightly.

# %% [markdown]
# ## Implementing an actual run with created API requests framework. ##
#
# Return to [Table of content:](#Table-of-content:)

# %%
hn_stories, request_failed = api_requests(n_requests=1000, url=url, sleep_time=.75, 
                                       target_keys=target_keys, params=params)
# Out:
# Request: 1000; Frequency: 0.4687252955027714 requests/s

# %%
hn_stories
# Out:
#      objectID                                              title  \
# 0    21456399                 Ask HN: How is your mental health?
# 1    21455739  Factual Inaccuracies of “Facebook Libra Is Arc...
# 2    21455276  AT&T to pay $60M over U.S. allegations it lied...
# 3    21455231  Risky Mortgage Bonds Are Back and Delinquencie...
# 4    21455033   World Scientists’ Warning of a Climate Emergency
# ..        ...                                                ...
# 495  21352277                                          Mir Books
# 496  21352239                  Double Slit Experiment No Mystery
# 497  21352161                Gmail marking email from me as spam
# 498  21352045   An Illustrated Guide to OAuth and OpenID Connect
# 499  21351695  Show HN: MNML – 1v1 turn-based strategy game b...
#
#                    created_at  points  num_comments  \
# 0    2019-11-05T20:36:52.000Z     108            88
# 1    2019-11-05T19:26:41.000Z     101            28
# 2    2019-11-05T18:39:30.000Z     123            75
# 3    2019-11-05T18:35:20.000Z     152            90
# 4    2019-11-05T18:17:21.000Z     103            71
# ..                        ...     ...           ...
# 495  2019-10-25T05:58:41.000Z     132            28
# 496  2019-10-25T05:50:39.000Z     106           116
# 497  2019-10-25T05:31:49.000Z     475           392
# 498  2019-10-25T05:02:18.000Z     431            74
# 499  2019-10-25T03:49:29.000Z     127            29
#
#                                                    url
# 0                                                 None
# 1    https://tonyarcieri.com/factual-inaccuracies-o...
# 2    https://www.reuters.com/article/us-at-t-settle...
# 3    https://www.bloomberg.com/news/articles/2019-1...
# 4    https://academic.oup.com/bioscience/advance-ar...
# ..                                                 ...
# 495                             https://mirtitles.org/
# 496  https://billwadge.wordpress.com/2019/10/25/dou...
# 497  https://www.mail-archive.com/mailop@mailop.org...
# 498  https://developer.okta.com/blog/2019/10/21/ill...
# 499                                   https://mnml.gg/
#
# [500000 rows x 6 columns]

# %%
request_failed
# Out:
# array([], dtype=float64)

# %% [markdown]
# ## Save the dataset into CSV file. ##
#
# Return to [Table of content:](#Table-of-content:)
#
# ---
# __Save the dataset as .csv format.__

# %%
hn_stories.to_csv("hn_stories.csv", index=False, header=True, sep=",")

# %% [markdown]
# ## Notes for future reference. ##
#
# __List of things to take note in the future:__
#
# * The API endpoints may have changed.
# * Useful data such as `points` and `num_comments` may be outdated.
# * Hacker News might impose a requirement for API authentication.
# * Terms & condition, and license may be updated. It might introduce some limitations to data usage.
#
# Return to [Table of content:](#Table-of-content:)
