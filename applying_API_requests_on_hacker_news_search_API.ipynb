# %% [markdown]
# # Applying API Requests On Hacker News Search API. #
#
# ---
#
# ## Purpose of this project: ##
#
# The objective is to showcase my familiarity using API requests technique to collect data from [Hacker News Search][1]. [Here's][2] the link to the API documentation. After collecting the data, I will build a simple [data pipeline][3] to perform data cleaning.
#
# __Background info:__
#
# Hacker News is a sites where people can share stories, sites, and articles or ask questions or post hiring notices.
#
#
# ## Table of content: ##
#
# * Find an efficient API requests framework and do a test run.
#     * [Strategising the API request procedure.](#Strategising-the-API-request-procedure.)
#     * [Creating an API requests framework and do a test run.](#Creating-an-API-requests-framework-and-do-a-test-run.)
# * Implement an actual run with the API requests framework and save it into CSV file.
#     * [Implementing an actual run with created API requests framework.](#Implementing-an-actual-run-with-created-API-requests-framework.)
#     * [Save the dataset into CSV file.](#Save-the-dataset-into-CSV-file.)
# * [Notes for future reference.](#Notes-for-future-reference.)
#
# [1]:https://hn.algolia.com/
# [2]:https://hn.algolia.com/api
# [3]:https://hn.algolia.com/api
# [4]:https://hn.algolia.com/api

# %%
import requests
import pandas as pd
from pprint import pprint

# %% [markdown]
# ## Strategising the API request procedure. ##
#
# Return to [Table of content:](#Table-of-content:)
#
# ---
#
# Hacker News API limits the number of API requests from a single IP to 10,000 per hour according to the API documentation. I will have to ensure the requests runs within the rate limit at a constant interval and monitor the requests frequency to avoid breaching the rate limit rule and overloading the server. Each request page will contain 500 stories.
#
# __Here's the endpoint that I will make a `get` request to:__
#
# - __hn.algolia.com/api/v1/search_by_date?__: This endpoint will collect stories starting from the lastest date.
#
# __Here're the `get` requests parameters:__
#
# - __page:__ From page 0 to 4,999.
# - __hitsPerPage:__ 300 stories per request page.
# - __tags:__ Data must be "story" type, not "ask".
# - __numericFilters:__ Story must have more than 100 points.

# %% [markdown]
# ## Creating an API requests framework and do a test run. ##
#
# Return to [Table of content:](#Table-of-content:)
#
# ---
#
# Before doing an actual run, I will first __observe the result of the API endpoint, create an API requests framework, and do a test run.__

# %%
params = {
    "page": 0,
    "hitsPerPage": 10,
    "tags": "story",
    "numericFilters": "points > 100, created_at_i < 1573344000"
}

response = requests.get("https://hn.algolia.com/api/v1/search_by_date?", params=params)
print("Request status: {}".format(response.status_code))
print("Type: {}; Result: {}".format(type(response.json()), pprint(response.json())))
# Out:
# Request status: 200
# {'exhaustiveNbHits': False,
#  'hits': [{'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'justin66'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'Rust 2020: GUI and '
#                                                    'Community'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'https://raphlinus.github.io/rust/druid/2019/10/31/rust-2020.html'}},
#            '_tags': ['story',
#                      'author_justin66',
#                      'story_21495338',
#                      'front_page'],
#            'author': 'justin66',
#            'comment_text': None,
#            'created_at': '2019-11-09T23:46:07.000Z',
#            'created_at_i': 1573343167,
#            'num_comments': 37,
#            'objectID': '21495338',
#            'parent_id': None,
#            'points': 152,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'Rust 2020: GUI and Community',
#            'url': 'https://raphlinus.github.io/rust/druid/2019/10/31/rust-2020.html'},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'gyc'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'Viral Tweet About Apple '
#                                                    'Card Leads to Goldman '
#                                                    'Sachs Probe'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'https://www.bloomberg.com/news/articles/2019-11-09/viral-tweet-about-apple-card-leads-to-probe-into-goldman-sachs'}},
#            '_tags': ['story', 'author_gyc', 'story_21494673'],
#            'author': 'gyc',
#            'comment_text': None,
#            'created_at': '2019-11-09T21:57:36.000Z',
#            'created_at_i': 1573336656,
#            'num_comments': 148,
#            'objectID': '21494673',
#            'parent_id': None,
#            'points': 129,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'Viral Tweet About Apple Card Leads to Goldman Sachs Probe',
#            'url': 'https://www.bloomberg.com/news/articles/2019-11-09/viral-tweet-about-apple-card-leads-to-probe-into-goldman-sachs'},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'hhs'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'Narcissistic CEOs weaken '
#                                                    'collaboration and '
#                                                    'integrity'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'https://www.gsb.stanford.edu/insights/narcissistic-ceos-weaken-collaboration-integrity'}},
#            '_tags': ['story', 'author_hhs', 'story_21494295'],
#            'author': 'hhs',
#            'comment_text': None,
#            'created_at': '2019-11-09T20:56:58.000Z',
#            'created_at_i': 1573333018,
#            'num_comments': 80,
#            'objectID': '21494295',
#            'parent_id': None,
#            'points': 150,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'Narcissistic CEOs weaken collaboration and integrity',
#            'url': 'https://www.gsb.stanford.edu/insights/narcissistic-ceos-weaken-collaboration-integrity'},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': '0x0f0f0f'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'Fast Markov chains in ~20 '
#                                                    'lines of sh, grep, cut and '
#                                                    'Awk'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'https://0x0f0f0f.github.io/posts/2019/11/really-fast-markov-chains-in-~20-lines-of-sh-grep-cut-and-awk/'}},
#            '_tags': ['story',
#                      'author_0x0f0f0f',
#                      'story_21493761',
#                      'front_page'],
#            'author': '0x0f0f0f',
#            'comment_text': None,
#            'created_at': '2019-11-09T19:37:40.000Z',
#            'created_at_i': 1573328260,
#            'num_comments': 34,
#            'objectID': '21493761',
#            'parent_id': None,
#            'points': 292,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'Fast Markov chains in ~20 lines of sh, grep, cut and Awk',
#            'url': 'https://0x0f0f0f.github.io/posts/2019/11/really-fast-markov-chains-in-~20-lines-of-sh-grep-cut-and-awk/'},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'Rochus'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'Show HN: LuaJIT '
#                                                    'assembler/assembly '
#                                                    'language for direct '
#                                                    'bytecode programming'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'https://github.com/rochus-keller/LjTools'}},
#            '_tags': ['story', 'author_Rochus', 'story_21493410', 'show_hn'],
#            'author': 'Rochus',
#            'comment_text': None,
#            'created_at': '2019-11-09T18:49:07.000Z',
#            'created_at_i': 1573325347,
#            'num_comments': 20,
#            'objectID': '21493410',
#            'parent_id': None,
#            'points': 127,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'Show HN: LuaJIT assembler/assembly language for direct '
#                     'bytecode programming',
#            'url': 'https://github.com/rochus-keller/LjTools'},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'pmoriarty'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'Haskell and Rust'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'https://www.fpcomplete.com/blog/2018/11/haskell-and-rust'}},
#            '_tags': ['story', 'author_pmoriarty', 'story_21492880'],
#            'author': 'pmoriarty',
#            'comment_text': None,
#            'created_at': '2019-11-09T17:43:49.000Z',
#            'created_at_i': 1573321429,
#            'num_comments': 106,
#            'objectID': '21492880',
#            'parent_id': None,
#            'points': 131,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'Haskell and Rust',
#            'url': 'https://www.fpcomplete.com/blog/2018/11/haskell-and-rust'},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'simonebrunozzi'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'The FCC Has Fined '
#                                                    'Robocallers $208M, '
#                                                    'Collected $6,790'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'https://www.wsj.com/articles/the-fcc-has-fined-robocallers-208-million-its-collected-6-790-11553770803?mod=rsswn'}},
#            '_tags': ['story',
#                      'author_simonebrunozzi',
#                      'story_21492782',
#                      'front_page'],
#            'author': 'simonebrunozzi',
#            'comment_text': None,
#            'created_at': '2019-11-09T17:27:39.000Z',
#            'created_at_i': 1573320459,
#            'num_comments': 342,
#            'objectID': '21492782',
#            'parent_id': None,
#            'points': 750,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'The FCC Has Fined Robocallers $208M, Collected $6,790',
#            'url': 'https://www.wsj.com/articles/the-fcc-has-fined-robocallers-208-million-its-collected-6-790-11553770803?mod=rsswn'},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'bookofjoe'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'Effects of Vitamin D and '
#                                                    'Omega-3 Fatty Acid on '
#                                                    'Biomarkers of '
#                                                    'Inflammation'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'http://clinchem.aaccjnls.org/content/early/2019/10/23/clinchem.2019.306902'}},
#            '_tags': ['story', 'author_bookofjoe', 'story_21492631'],
#            'author': 'bookofjoe',
#            'comment_text': None,
#            'created_at': '2019-11-09T16:59:39.000Z',
#            'created_at_i': 1573318779,
#            'num_comments': 38,
#            'objectID': '21492631',
#            'parent_id': None,
#            'points': 118,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'Effects of Vitamin D and Omega-3 Fatty Acid on Biomarkers '
#                     'of Inflammation',
#            'url': 'http://clinchem.aaccjnls.org/content/early/2019/10/23/clinchem.2019.306902'},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'garyclarke27'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'German solar and wind are '
#                                                    'triple the cost of French '
#                                                    'nuclear, last half as '
#                                                    'long'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'https://www.nextbigfuture.com/2019/11/france-spent-less-on-nuclear-to-get-about-double-what-germany-gets-from-renewables.html'}},
#            '_tags': ['story', 'author_garyclarke27', 'story_21492596'],
#            'author': 'garyclarke27',
#            'comment_text': None,
#            'created_at': '2019-11-09T16:55:27.000Z',
#            'created_at_i': 1573318527,
#            'num_comments': 208,
#            'objectID': '21492596',
#            'parent_id': None,
#            'points': 273,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'German solar and wind are triple the cost of French '
#                     'nuclear, last half as long',
#            'url': 'https://www.nextbigfuture.com/2019/11/france-spent-less-on-nuclear-to-get-about-double-what-germany-gets-from-renewables.html'},
#           {'_highlightResult': {'author': {'matchLevel': 'none',
#                                            'matchedWords': [],
#                                            'value': 'rahuldottech'},
#                                 'title': {'matchLevel': 'none',
#                                           'matchedWords': [],
#                                           'value': 'Falsehoods Programmers '
#                                                    'Believe About Names '
#                                                    '(2010)'},
#                                 'url': {'matchLevel': 'none',
#                                         'matchedWords': [],
#                                         'value': 'https://www.kalzumeus.com/2010/06/17/falsehoods-programmers-believe-about-names/'}},
#            '_tags': ['story', 'author_rahuldottech', 'story_21492464'],
#            'author': 'rahuldottech',
#            'comment_text': None,
#            'created_at': '2019-11-09T16:36:15.000Z',
#            'created_at_i': 1573317375,
#            'num_comments': 133,
#            'objectID': '21492464',
#            'parent_id': None,
#            'points': 142,
#            'story_id': None,
#            'story_text': None,
#            'story_title': None,
#            'story_url': None,
#            'title': 'Falsehoods Programmers Believe About Names (2010)',
#            'url': 'https://www.kalzumeus.com/2010/06/17/falsehoods-programmers-believe-about-names/'}],
#  'hitsPerPage': 10,
#  'nbHits': 103132,
#  'nbPages': 100,
#  'page': 0,
#  'params': 'advancedSyntax=true&analytics=true&analyticsTags=backend&hitsPerPage=10&numericFilters=points+%3E+100%2C+created_at_i+%3C+1573344000&page=0&tags=story',
#  'processingTimeMS': 6,
#  'query': ''}
# Type: <class 'dict'>; Result: None

# %% [markdown]
# ---
#
# The requests to the API endpoint is successful. The collected data is a __"story" type__ and the stories are __ordered by date__ starting from the latest. Each story contains __more than 100 points__. Next is to ensure the `hitsPerPage` outputs __500 stories__ exactly. The `hits` key inside the dictionary contains a list of all the stories. Hence, I only have to count the length of the list in order to find out the number of results.

# %%
params = {
    "page": 0,
    "hitsPerPage": 500,
    "tags": "story",
    "numericFilters": "points > 100, created_at_i < 1573344000"
}
response = requests.get("https://hn.algolia.com/api/v1/search_by_date?", params=params)
print("Request status: {}".format(response.status_code))
print("Type: {}; Result: {}".format(type(response.json()), len(response.json()["hits"])))
# Out:
# Request status: 200
# Type: <class 'dict'>; Result: 500

# %% [markdown]
# ---
#
# Looking at the result above, the request outputs 500 stories exactly. The next step is __locate the target keys__ inside the dictionary in order to collect relevant data for analysis.
#
# __Here're the target keys that can be useful for analysis later:__
#
# 1. __objectID:__ It is a story ID. Might be useful if I need to make an API request to gather more information on this specific story via __hn.algolia.com/api/v1/items/:id__ endpoint.
# 1. __title:__ For finding out the topic.
# 1. __created_at:__ For determining how current the story is.
# 1. __points:__ For measuring the popularity of the story.
# 1. __num_comments:__ For measuring the readers' participation and interest on the particular story.
# 1. __url:__ For finding the most referred sites.
#
# The `hits` key inside the dictionary contains a list of all the stories. Hence, I just have to convert the list of stories into a DataFrame and filter the columns by the target keys.

# %%
ls_hits = response.json()["hits"]

columns = [
    "objectID", "title", "created_at", "points", "num_comments", "url"
]

pd.DataFrame(data=ls_hits)[columns]
# Out:
#      objectID                                              title  \
# 0    21495338                       Rust 2020: GUI and Community
# 1    21494673  Viral Tweet About Apple Card Leads to Goldman ...
# 2    21494295  Narcissistic CEOs weaken collaboration and int...
# 3    21493761  Fast Markov chains in ~20 lines of sh, grep, c...
# 4    21493410  Show HN: LuaJIT assembler/assembly language fo...
# ..        ...                                                ...
# 495  21387480    Mass cellphone surveillance experiment in Spain
# 496  21387299  How to force disgruntled worker not to publicl...
# 497  21387254  'Zen curtain' saves birds from hitting glass w...
# 498  21386932                         Swish: SWI Prolog Notebook
# 499  21386677  Leonard Kleinrock on what went wrong with the ...
#
#                    created_at  points  num_comments  \
# 0    2019-11-09T23:46:07.000Z     152            37
# 1    2019-11-09T21:57:36.000Z     129           148
# 2    2019-11-09T20:56:58.000Z     150            80
# 3    2019-11-09T19:37:40.000Z     292            34
# 4    2019-11-09T18:49:07.000Z     127            20
# ..                        ...     ...           ...
# 495  2019-10-29T14:24:28.000Z     361           224
# 496  2019-10-29T14:07:02.000Z     106            44
# 497  2019-10-29T14:03:38.000Z     195            62
# 498  2019-10-29T13:36:06.000Z     146            53
# 499  2019-10-29T13:10:44.000Z     322           312
#
#                                                    url
# 0    https://raphlinus.github.io/rust/druid/2019/10...
# 1    https://www.bloomberg.com/news/articles/2019-1...
# 2    https://www.gsb.stanford.edu/insights/narcissi...
# 3    https://0x0f0f0f.github.io/posts/2019/11/reall...
# 4             https://github.com/rochus-keller/LjTools
# ..                                                 ...
# 495  https://cfenollosa.com/blog/mass-cellphone-sur...
# 496  https://workplace.stackexchange.com/questions/...
# 497  https://www.abc.net.au/news/2019-10-28/the-cur...
# 498                      https://swish.swi-prolog.org/
# 499  https://www.latimes.com/opinion/story/2019-10-...
#
# [500 rows x 6 columns]

# %% [markdown]
# ---
#
# __Find the maximum request frequency to avoid breaching the rate limit rule.__

# %%
# This is to find the maximum request frequency to avoid breaching the rate limit rule. 
def rate_limit(total_requests, seconds):
    rate_limit = total_requests / seconds
    print("Request: {}; Max frequency: {} requests/s".format(total_requests, rate_limit))
    
rate_limit(10000, 3600)
# Out:
# Request: 10000; Max frequency: 2.7777777777777777 requests/s

# %% [markdown]
# ---
#
# Looking at the result above, the request frequency should not exceed 2.7 requests per second. If I were to make 1 request per second, it will take 1,000 seconds to complete it, which is about 17 minutes.

# %% [markdown]
# __Find the optimal request rate.__

# %%
def optimal_request_rate(n_requests, sleep_time):
    from time import time, sleep
    from IPython.core.display import clear_output
    
    # Create a 'requested' variable to keep track of the current request made.
    requested = 0
    # Time the request to track the request frequency.
    start = time() 
    
    for n in range(0, n_requests):
        requested += 1
        sleep(sleep_time)

        elapsed_time = time() - start

        print("Request: {}; Frequency: {} requests/s".format(requested, requested / elapsed_time))
        clear_output(wait=True)
        
optimal_request_rate(10, 1)
# Out:
# Request: 10; Frequency: 0.9944484917877525 requests/s

# %%
params = {
    "page": 0,
    "hitsPerPage": 500,
    "tags": "story",
    "numericFilters": "points > 100, created_at_i < 1573344000"
}

target_keys = [
    "objectID", "title", "created_at", "points", "num_comments", "url"
]

url = "https://hn.algolia.com/api/v1/search_by_date?"

def api_requests(n_requests, url, sleep_time, target_keys=None, params={}):
    import numpy as np
    from time import time, sleep
    from IPython.core.display import clear_output
    from warnings import warn
    
    # Create a list to store unsuccessful requests for reference later.
    # Create a 'requested' variable to keep track of the current request made.
    request_failed = np.array([])
    requested = 0
    
    # Create empty DataFrame to store the data.
    df = pd.DataFrame(data=[])

    # Time the request to ensure it is staying within the rate limit.
    start = time() 
    # Set the parameters when the running the api requests.
    params_dict = params.copy()

    # Make n number of requests, which equals to n pages.
    for page in range(0, n_requests):

        # Break the loop if the total request is greater than n_requests (just in case).
        if requested > n_requests:
            warn("Request number is greater than {}}.".format(n_requests))
            break
            
        requested += 1
        response = requests.get("{}".format(url), params=params_dict)
        
        # Rewrite the page number for each request.
        params_dict["page"] += 1
        
        # Sleep for n seconds.
        sleep(sleep_time)
        elapsed_time = time() - start
        
        # Warn unsuccessful status code.
        if response.status_code != 200:
            warn('Request: {}; Status code: {}'.format(requested, response.status_code))
            request_failed = np.append(request_failed, [requested, response.status_code])
        
        # Append the items to the list if the request is successful.
        if response.status_code == 200:
            ls_data = response.json()["hits"]
        
        # Print out the number of requests and time to monitor the progress.
        print("Request: {}; Frequency: {} requests/s".format(requested, requested / elapsed_time))
        clear_output(wait=True)
        
        # If the requests outputs 0 result, stop the API requests.
        results = len(response.json()["hits"])
        if  results == 0:
            warn("Request outputs no more result.")
            return df, request_failed
        
        # Add the collected data to DataFrame. 
        if target_keys: 
            df_collected_data = pd.DataFrame(data=ls_data)[target_keys]
        else:
            df_collected_data = pd.DataFrame(data=ls_data)
        df = pd.concat(objs=[df, df_collected_data], axis=0, join='outer')

    return df, request_failed

# %% [markdown]
# __Do a test run with only 5 API requests.__

# %%
hn_stories, request_failed = api_requests(n_requests=5, url=url, sleep_time=1, 
                                          target_keys=target_keys, params=params)
# Out:
# /Users/lioneltay/Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:67: UserWarning: Request outputs no more result.

# %%
hn_stories
# Out:
#      objectID                                              title  \
# 0    21495338                       Rust 2020: GUI and Community
# 1    21494673  Viral Tweet About Apple Card Leads to Goldman ...
# 2    21494295  Narcissistic CEOs weaken collaboration and int...
# 3    21493761  Fast Markov chains in ~20 lines of sh, grep, c...
# 4    21493410  Show HN: LuaJIT assembler/assembly language fo...
# ..        ...                                                ...
# 495  21282680                 DoNotPay app waits on hold for you
# 496  21282647                              Haskell in Production
# 497  21282009                                        OpenBSD 6.6
# 498  21281724    DNS 101: An Introduction to Domain Name Servers
# 499  21281525         BrachioGraph – a cheap, simple pen plotter
#
#                    created_at  points  num_comments  \
# 0    2019-11-09T23:46:07.000Z     152            37
# 1    2019-11-09T21:57:36.000Z     129           148
# 2    2019-11-09T20:56:58.000Z     150            80
# 3    2019-11-09T19:37:40.000Z     292            34
# 4    2019-11-09T18:49:07.000Z     127            20
# ..                        ...     ...           ...
# 495  2019-10-17T14:53:39.000Z     130            82
# 496  2019-10-17T14:50:57.000Z     200           237
# 497  2019-10-17T13:49:36.000Z     224            89
# 498  2019-10-17T13:21:45.000Z     250            38
# 499  2019-10-17T13:01:05.000Z     596           104
#
#                                                    url
# 0    https://raphlinus.github.io/rust/druid/2019/10...
# 1    https://www.bloomberg.com/news/articles/2019-1...
# 2    https://www.gsb.stanford.edu/insights/narcissi...
# 3    https://0x0f0f0f.github.io/posts/2019/11/reall...
# 4             https://github.com/rochus-keller/LjTools
# ..                                                 ...
# 495  https://techcrunch.com/2019/10/16/avoid-waitin...
# 496  http://felixmulder.com/writing/2019/10/05/Hask...
# 497                    https://www.openbsd.org/66.html
# 498  https://www.redhat.com/sysadmin/dns-domain-nam...
# 499     https://brachiograph.readthedocs.io/en/latest/
#
# [1000 rows x 6 columns]

# %%
request_failed
# Out:
# array([], dtype=float64)

# %%
hn_stories.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ---
# The API requests framework is successful and there is no failed request. The only the exception is that the time interval between each request was halfed, so there might be room to lower the `sleep_time` slightly.
#
# It is my `api_requests` function that generates the warning above. The warning indicates that there is no more result to retrieve, thus the API request stops. This might be due to the API requests limitation set by the Hacker News. Nevertheless, the purpose of this project is showcase the my familiarity with API requests and workflow. Hence, I will continue to implement an actual run to demonstrate my workflow.

# %% [markdown]
# ## Implementing an actual run with created API requests framework. ##
#
# Return to [Table of content:](#Table-of-content:)

# %%
hn_stories, request_failed = api_requests(n_requests=1000, url=url, sleep_time=.75, 
                                          target_keys=target_keys, params=params)
# Out:
# /Users/lioneltay/Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:67: UserWarning: Request outputs no more result.

# %%
hn_stories
# Out:
#      objectID                                              title  \
# 0    21495338                       Rust 2020: GUI and Community
# 1    21494673  Viral Tweet About Apple Card Leads to Goldman ...
# 2    21494295  Narcissistic CEOs weaken collaboration and int...
# 3    21493761  Fast Markov chains in ~20 lines of sh, grep, c...
# 4    21493410  Show HN: LuaJIT assembler/assembly language fo...
# ..        ...                                                ...
# 495  21282680                 DoNotPay app waits on hold for you
# 496  21282647                              Haskell in Production
# 497  21282009                                        OpenBSD 6.6
# 498  21281724    DNS 101: An Introduction to Domain Name Servers
# 499  21281525         BrachioGraph – a cheap, simple pen plotter
#
#                    created_at  points  num_comments  \
# 0    2019-11-09T23:46:07.000Z     152            37
# 1    2019-11-09T21:57:36.000Z     129           148
# 2    2019-11-09T20:56:58.000Z     150            80
# 3    2019-11-09T19:37:40.000Z     292            34
# 4    2019-11-09T18:49:07.000Z     127            20
# ..                        ...     ...           ...
# 495  2019-10-17T14:53:39.000Z     130            82
# 496  2019-10-17T14:50:57.000Z     200           237
# 497  2019-10-17T13:49:36.000Z     224            89
# 498  2019-10-17T13:21:45.000Z     250            38
# 499  2019-10-17T13:01:05.000Z     596           104
#
#                                                    url
# 0    https://raphlinus.github.io/rust/druid/2019/10...
# 1    https://www.bloomberg.com/news/articles/2019-1...
# 2    https://www.gsb.stanford.edu/insights/narcissi...
# 3    https://0x0f0f0f.github.io/posts/2019/11/reall...
# 4             https://github.com/rochus-keller/LjTools
# ..                                                 ...
# 495  https://techcrunch.com/2019/10/16/avoid-waitin...
# 496  http://felixmulder.com/writing/2019/10/05/Hask...
# 497                    https://www.openbsd.org/66.html
# 498  https://www.redhat.com/sysadmin/dns-domain-nam...
# 499     https://brachiograph.readthedocs.io/en/latest/
#
# [1000 rows x 6 columns]

# %%
request_failed
# Out:
# array([], dtype=float64)

# %% [markdown]
# ## Save the dataset into CSV file. ##
#
# Return to [Table of content:](#Table-of-content:)
#
# ---
# __Save the dataset as .csv format.__

# %%
hn_stories.to_csv("hn_stories.csv", index=False, header=True, sep=",")

# %% [markdown]
# ## Notes for future reference. ##
#
# __List of things to take note in the future:__
#
# * The API endpoints may have changed.
# * Useful data such as `points` and `num_comments` may be outdated.
# * Hacker News might impose a requirement for API authentication.
# * Terms & condition, and license may be updated. It might introduce some limitations to data usage.
#
# Return to [Table of content:](#Table-of-content:)
